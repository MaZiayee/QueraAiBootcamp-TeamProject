# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: center;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=5>
# سوال دو یادگیری ماشین

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# سوال: پس از آن الگوریتم K-means را برای k هایی از ۱ تا ۲۰ اجرا کرده و با محاسبه‌ی مجموع مجذورات درون خوشه‌ای  (Within-Cluster Sum of Square)، مقدار مناسبی برای هایپرپارامتر k انتخاب کنید. توجه کنید که بخش زیادی از نمره‌ی این بخش مربوط به نحوه‌ی انتخاب مقدار k است و چنان‌چه روش‌های تدریس‌شده و معمول پاسخگوی حل مسئله نبود،انتظار می‌رود با جستجو و مطالعه‌ی بیشتر، روشی مناسب برای رفع چالش‌های احتمالی پیشنهاد دهید.

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Divar.csv")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18640\1381234337.py:1: DtypeWarning: Columns (11,27,29,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Divar.csv")

# %%
# ذخیره‌ی ویژگی‌هایی که برای خوشه بندی استغاده میخوایم بکنیم
X = df[['transformable_price', 'location_latitude','location_longitude']]
# داده‌های ناقص رو حذف میکنیم
X = X.dropna()
# نرمال سازی میکنیم
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
Within_Cluster_Sum_of_Square = []

# %%
# از یک تا بیست k_means اجرای الگوریتم
for k in range(1,21):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    Within_Cluster_Sum_of_Square.append(kmeans.inertia_)

# %%
# رسم نمودار
plt.plot(range(1,21), Within_Cluster_Sum_of_Square, marker='o')
plt.xlabel("k")
plt.ylabel("Within_Cluster_Sum_of_Square")
plt.title("Machine Learning Question 2 Diagram")
plt.grid(True)
plt.show()

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# باتوجه به نمودار از k یک تا چهار مقدار Within_Cluster_Sum_of_Square با شدت بیشتری نسبت به k چهار به بعد کاهش پیدا میکنه
# <br>
#     میتونیم k=5 رو تعداد مناسب خوشه‌ها انتخاب کنیم چون بعد از این عدد با اینکه تعداد خوشه ها هی زیاد میشه ولی کاهش Within_Cluster_Sum_of_Square به نسبت قبل از آن کمتره و یه جورایی تغییر خیلی زیادی توی کیفیت خوشه‌بندی ایجاد نمیکنه
